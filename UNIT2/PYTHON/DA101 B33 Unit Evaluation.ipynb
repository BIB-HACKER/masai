# %%
import requests
from bs4 import BeautifulSoup

# %%
def page(url):
    response = requests.get(url)
    if response.status_code==200:
        return response.text
    else:
        return None

# %%
doc = page("https://www.hirist.tech/search/data%20analyst.html?locIds=0&exp=0&ref=homepage")

# %%
doc
# Out:
# '<!doctype html><html lang="en"><head>\n      \n      \n      \n      \n      \n      <link rel="shortcut icon" href=https://static.hirist.com/resources/img/hirist/favicon.ico></link>\n      </head><meta name="viewport" content="width=device-width,initial-scale=1"><img id="lcpmob" height="900" style="pointer-events:none;position:absolute;top:0;left:0;width:90vw" alt="" src="data:image/png;base64,..."/> <img id="lcpweb" height="400" style="pointer-events:none;position:absolute;top:0;left:0;width:90vw" alt="" src="data:image/png;base64,..."/><link rel="dns-prefetch preconnect" href="https://staticlogo.hirist.com"/><link rel="dns-prefetch preconnect" href="https://job-static.hirist.com"/><link rel="dns-prefetch preconnect" href="https://hirist-assets.s3.ap-south-1.amazonaws.com"/><link rel="dns-prefetch preconnect" href="https://billboard.iimjobs.com"/><link rel="dns-prefetch preconnect" href="https://d3qr48lsanmyop.cloudfront.net"/><link rel="dns-prefetch" href="https://www.googletagma
# ...

# %%
def com_name(doc):
    company=[]
    soup = BeautifulSoup(doc, 'html.parser')
    names = soup.find('span', class_='dark_grey align-title')
    return names
    # for name in names:
    #     company.append(name.title)
    # return company

# %%
company = com_name(doc)
company

# %%
# def com_title(doc):
#     title=[]
soup = BeautifulSoup(doc)
soup.find('div', class_="head").find('div', class_="job-title")
    # return names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 # def com_title(doc):
#       2 #     title=[]
#       3 soup = BeautifulSoup(doc)
# ----> 4 soup.find('div', class_="head").find('div', class_="job-title")
#       5     # return names
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
title = com_title(doc)
title

# %%
exp = BeautifulSoup(doc)
exp.find_all('div', class_='job-fields')[0].find_all('spain', class_='dark_grey')[0]

# %%
pip install selenium

# %%
from selenium import webdriver

# %%
webdriver.Edge(executable_path = r"Programming\MASAI\PYTHON\msedgedriver.exe")

# %% [markdown]
# # SORRY FOR THIS PERFORMANCE
